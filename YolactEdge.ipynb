# %%
# %cd /home/user8001/AI-EXPO/yolact_edge-master
# Out:
# /home/user8001/AI-EXPO/yolact_edge-master

# %%
# Display qualitative results on COCO. From here on I'll use a confidence threshold of 0.3.
# file_path = "data/project"
# output_path = "output_data"
# !python eval.py --disable_tensorrt --config=yolact_edge_config --trained_model=weights/yolact_edge_3749_30000.pth --score_threshold=0.3 --top_k=100 --video_multiframe=2 --trt_batch_size 2 --video=1
# !python eval.py --disable_tensorrt --config=yolact_edge_config --trained_model=weights/yolact_edge_43_400000.pth --score_threshold=0.3 --top_k=100 --images={file_path}:{output_path}

# %%
# file_path = "data/video/test_video.mp4"
# output_path = "results/output_video2.mp4"
# !python eval.py --disable_tensorrt --config=yolact_edge_config --trained_model=weights/yolact_edge_43_400000.pth --score_threshold=0.3 --top_k=100 --video={file_path}:{output_path}

# %%
# !pip install gitpython

# %%
# !python train.py --config=yolact_base_config
# Out:
# 2022-05-01 10:13:21.125324: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# [05/01 10:13:21 yolact.train]: Args: train.py --config=yolact_base_config
# loading annotations into memory...
# Done (t=5.31s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=6.35s)
# creating index...
# index created!
# [05/01 10:13:36 yolact.train]: Initializing weights...
# [05/01 10:13:36 yolact.train]: Begin training!
# /home/user8001/AI-EXPO/yolact_edge-master/yolact_edge/utils/augmentations.py:414: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   mode = random.choice(self.sample_options)
# ...

# %%
# import torch 
# print(torch.__version__)
# print(torch.version.cuda)
# torch.cuda.is_available()

# %%
# !pip install torch==1.7.1+cu110 torchvision==0.8.2+cu110 torchaudio==0.7.2 -f https://download.pytorch.org/whl/torch_stable.html

# %%
# !python eval.py --disable_tensorrt --config=yolact_base_config --trained_model=weights/yolact_my_config_0_1000.pth --score_threshold=0.3 --top_k=100 --image=test.jpg:output_image.jpg
# Out:
# [05/01 10:24:30 yolact.eval]: Loading model...
# [05/01 10:24:32 yolact.eval]: Model loaded.

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
from PIL import Image 
plt.rcParams["figure.figsize"] = (15.0, 15.0)

# %%
src = Image.open('output_image.jpg')
plt.figure("src")
plt.imshow(src)
